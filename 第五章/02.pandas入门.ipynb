# %%
import pandas as pd

#构造DataFrame --创建数据集（学员成绩信息）
df = pd.DataFrame([
    {"姓名":"张三", "语文":80, "数学":85, "英语":90},
    {"姓名":"李四", "语文":75, "数学":80, "英语":85},
    {"姓名":"王五", "语文":90, "数学":95, "英语":100},
    {"姓名":"赵六", "语文":60, "数学":65, "英语":70},
    {"姓名":"孙七", "语文":85, "数学":90, "英语":95},
    {"姓名":"周八", "语文":70, "数学":75, "英语":80},
    {"姓名":"吴九", "语文":55, "数学":60, "英语":65},
    {"姓名":"郑十", "语文":45, "数学":50, "英语":55}
])

#统计计算
print(f"语文最高分:{df['语文'].max()}, 语文最低分:{df['语文'].min()}, 平均分:{df['语文'].mean():.2f}")
print(f"数学最高分:{df['数学'].max()}, 数学最低分:{df['数学'].min()}, 平均分:{df['数学'].mean():.2f}")
print(f"英语最高分:{df['英语'].max()}, 英语最低分:{df['英语'].min()}, 平均分:{df['英语'].mean():.2f}")
# Out:
# 语文最高分:90, 语文最低分:45, 平均分:70.0
# 数学最高分:95, 数学最低分:50, 平均分:75.0
# 英语最高分:100, 英语最低分:55, 平均分:80.0

# %%
import pandas as pd
df1 = pd.DataFrame([
    {"姓名": "小智", "语文": 80, "数学": 85, "英语": 90},
    {"姓名": "小霞", "语文": 75, "数学": 80, "英语": 85},
    {"姓名": "小刚", "语文": 90, "数学": 95, "英语": 100}
])

df2 = pd.DataFrame({
    "姓名": ["小智", "小霞", "小刚"],
    "语文": [80, 75, 90],
    "数学": [85, 80, 95],
    "英语": [90, 85, 100]
})

df3 = pd.DataFrame([
    ["小智", 80, 85, 90],
    ["小霞", 75, 80, 85],
    ["小刚", 90, 95, 100]
], columns = ["姓名", "语文", "数学", "英语"])

df4 = pd.DataFrame([
    ["小智", 80, 85, 90],
    ["小霞", 75, 80, 85],
    ["小刚", 90, 95, 100]
], columns = ["姓名", "语文", "数学", "英语"], index = ['a', 'b', 'c'])

# DataFrame 常见属性 - index, columns, values, dtypes, shape, size
df4.index.tolist()# 索引
df4.columns.tolist()# 列名
df4.values.tolist()# 值
df4.dtypes# 数据类型
df4.shape# 形状
df4.size# 大小
# Out:
# 12

# %%
#Series创建
s1 = pd.Series([10, 20, 30, 40, 52])

s2 = pd.Series((10, 20, 30, 40, 52), index = ['a', 'b', 'c', 'd', 'e'])

s3 = pd.Series({'a':10, 'b':20, 'c':30, 'd':40, 'e':52})

s4 = df4['语文']

#Series常见属性 - index, values, dtype, shape, size
s3.index.tolist()# 索引
s3.values.tolist()# 值
s3.dtype# 数据类型
s3.shape# 形状
s3.size# 大小
# Out:
# 5
